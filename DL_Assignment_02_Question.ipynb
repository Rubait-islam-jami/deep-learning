# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubait-islam-jami/deep-learning/blob/main/DL_Assignment_02_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DL Assignment 02
#
# **Name:*MD.RUBAIT ISLAM JAMI*
#
# **Course Email:*rubaitjami278@gmail.com*
#
# This is a small assignment that connects topics from Module 1, 2, and 3.
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
# Explain gradient descent in detail. What is the main idea behind it? How does it help in minimizing the loss function? Explain the role of learning rate and describe what happens if the learning rate is too high or too low.

# %% [markdown]
# **Write** Answer 01:
# gradien descent is a method used to reduce the error of a model step by step.The main idea is to adjust the models parameters in such a way the loss function becomes as small as possible.
# It minimizes the loss function by updating model parameters in the opposite direction of the slope.
# If thr learning rate is too high the model may jump over the minimum point and fail to converge.If it is too low the training becomes very slow and may take a long time to reach minimum

# %% [markdown]
# # Question 02: [ Marks 10 ]
#
# What is forward propagation in an artificial neural network? Explain step by step how data moves from the input layer to the output layer.

# %% [markdown]
# ## Write Answer 02:
# Forward propagation is the process by which input data moves through a neural network to produce an output.
# in input layer each input is multiplied by its corresponding weight and a bias is added.after that an activation function is applied
# to introduce non-linearity.then reuslt passed to next layer and the process continues.
# Finally, the output layer produces the prediction.

# %% [markdown]
# # Question 03: [ Marks 15 ]
# Why do we need activation functions in neural networks? What would happen if we only used linear transformations without any activation function?

# %% [markdown]
# ## Write Answer 03:
# Activation functions are necessary because they allow neural networks to learn complex patterns.
#
# if we only used linear transformation then no matter how many layers we add the networks like a simple linear model.this wil solve complex problem. so without we can not solve non-linearity.

# %% [markdown]
# # Question 04: [ Marks 15 ]
#
# Explain the sigmoid activation function. Where is it used? What are its advantages and disadvantages? What problem does it cause during training?

# %% [markdown]
# ## Write Answer 04:
# the sigmoid activation function is a function that converts any input value into a value between 0 and 1.
#
# It is used in binary classification problems because its output can be think as a probalility.
# It is smooth curve and its output think as probability,Its disadvantages gradients becomes very small(Vanishing Gradient problem).in there the model learns very slowly

# %% [markdown]
# # Question 05: [ Marks 10 ]
# Explain the softmax activation function in simple words. Why is it used in multi-class classification problems? How is it different from sigmoid?

# %% [markdown]
# ## Write Answer 05:
# The softmax function is used to convert multiple output values into a probabilities that add up to 1.If a model has to classify an image as a cat pr bird softmax will give probabilty for each class, highest probability is chosen as a the final prediction.
# The main different from sigmoid is used for binary classification and gives a single probability while softmax is used for multi-class classification probability gives across multiple classes

# %% [markdown]
# # Question 06: [ Marks 20 ]
#
# Explain the structure of an Artificial Neural Network in detail. Describe the role of the input layer, hidden layers, and output layer. How do weights, biases, and activation functions work together to transform input data into predictions? Illustrate your explanation with a simple example.

# %% [markdown]
# ## Write Answer 06:
# Three main layers:
# input layers: input layers receives the raw data.No calculations.
# hiddens layers: where the most of the computation happens.Each neuron in these layers takes inputs,multiple by weights adds a bias and then applies an activaton function.
# Output layers: gives final predictions
#
# weights determine how important input is biases help adjust the output and activation function introduce non linearity so the model can run complex relations.
#
# For example if we want to predict whether a person will get a loan ,the inputs could be age and income.These inputs pass through hidden layers patterns are learned then output layer gives final decision.

# %% [markdown]
# # Question 07: [ Marks 20 ]
#
#
# Train a neural network using TensorFlow Playground on any dataset other than XOR (for example, circles, spiral, or Gaussian). Use at least two hidden layers and select appropriate activation functions. Experiment with different numbers of neurons, learning rates, and regularization techniques.
#
# After training the model:
#
# Attach a screenshot of the model architecture and the final decision boundary.
#
# Report the training loss and any relevant observations.
#
# Analyze how the decision boundary evolved during training.
#
# Discuss whether the model shows signs of overfitting or underfitting.

# %% [markdown]
# ![Screenshot 2026-04-16 224551.png](data:image/png;base64,...)
# The model consists of two hidden layers.the first hidden layer contain 4 neurons and the second hidden layer contains 2 neurons.I used the sigmoid activation function with a learning rate 0.03..I aslo used a small regularization rate of 0.001 to help improve generalization.After about 1844 epochs ,the model achieved a training loss of 0.023.at the beginning the decision bondary was unclear but over time it became more structed .there no significant signs of underfitting also there is no strong evidence of overfitting .the model perfroms reasonabley well but could be improved with better activation functions
